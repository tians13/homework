# %%
import torch
import torch.nn as nn

class SimpleBlock(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(SimpleBlock, self).__init__()
        self.conv = nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1)
        self.relu = nn.ReLU()

    def forward(self, x):
        x = self.conv(x)
        x = self.relu(x)
        return x

def build_network(in_channels, out_channels_per_block, num_blocks):
    layers = []
    current_in_channels = in_channels
    for _ in range(num_blocks):
        block = SimpleBlock(current_in_channels, out_channels_per_block)
        layers.append(block)
        current_in_channels = out_channels_per_block
    network = nn.Sequential(*layers)
    return network

in_channels = 3
out_channels_per_block = 16
num_blocks = 4
network = build_network(in_channels, out_channels_per_block, num_blocks)
print(network)
# Out:
# Sequential(
#   (0): SimpleBlock(
#     (conv): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu): ReLU()
#   )
#   (1): SimpleBlock(
#     (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu): ReLU()
#   )
#   (2): SimpleBlock(
#     (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu): ReLU()
#   )
#   (3): SimpleBlock(
#     (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu): ReLU()
#   )
# )
